# %%
# Load packages
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
#import time
from subprocess import check_output

# %%
d = pd.read_csv('train (1).csv')

# %%
d.head()  # head method show only first 5 rows
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
col = d.columns # .columns gives columns names in data 
print(col)
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# renaming data columns
d.columns=['battery_power','bluetooth', 'clock_speed', 'dual_sim', 'front_cam', 'four_g',
       'internal_memory', 'mob_depth', 'mobile_wt', 'n_cores', 'primary_cam', 'px_height',
       'px_width', 'ram', 'screen_h', 'screen_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi', 'price_range']

# %%
d.describe()
# Out:
#        battery_power  bluetooth  clock_speed     dual_sim    front_cam  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g  internal_memory    mob_depth    mobile_wt      n_cores  \
# count  2000.000000      2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500        32.046500     0.501750   140.249000     4.520500
# std       0.499662        18.145715     0.288416    35.399655     2.287837
# min       0.000000         2.000000     0.100000    80.000000     1.000000
# 25%       0.000000        16.000000     0.200000   109.000000     3.000000
# 50%       1.000000        32.000000     0.500000   141.000000     4.000000
# 75%       1.000000        48.000000     0.800000   170.000000     7.000000
# max       1.000000        64.000000     1.000000   200.000000     8.000000
#
#        ...    px_height     px_width          ram     screen_h     screen_w  \
# count  ...  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean   ...   645.108000  1251.515500  2124.213000    12.306500     5.767000
# std    ...   443.780811   432.199447  1084.732044     4.213245     4.356398
# min    ...     0.000000   500.000000   256.000000     5.000000     0.000000
# 25%    ...   282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%    ...   564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%    ...   947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    ...  1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
#to check null entry
d.info()
d['primary_cam'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   battery_power    2000 non-null   int64
#  1   bluetooth        2000 non-null   int64
#  2   clock_speed      2000 non-null   float64
#  3   dual_sim         2000 non-null   int64
#  4   front_cam        2000 non-null   int64
#  5   four_g           2000 non-null   int64
#  6   internal_memory  2000 non-null   int64
#  7   mob_depth        2000 non-null   float64
#  8   mobile_wt        2000 non-null   int64
#  9   n_cores          2000 non-null   int64
#  10  primary_cam      2000 non-null   int64
#  11  px_height        2000 non-null   int64
#  12  px_width         2000 non-null   int64
#  13  ram              2000 non-null   int64
#  14  screen_h         2000 non-null   int64
#  15  screen_w         2000 non-null   int64
#  16  talk_time        2000 non-null   int64
#  17  three_g          2000 non-null   int64
#  18  touch_screen     2000 non-null   int64
#  19  wifi             2000 non-null   int64
#  20  price_range      2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB
# array([ 2,  6,  9, 14,  7, 10,  0, 15,  1, 18, 17, 11, 16,  4, 20, 13,  3,
#        19,  8,  5, 12])

# %%
d['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
d.price_range.value_counts()
# Out:
# 0    500
# 1    500
# 2    500
# 3    500
# Name: price_range, dtype: int64

# %%
d.hist(bins=30, figsize=(15, 15))
# Out:
# array([[<AxesSubplot:title={'center':'battery_power'}>,
#         <AxesSubplot:title={'center':'bluetooth'}>,
#         <AxesSubplot:title={'center':'clock_speed'}>,
#         <AxesSubplot:title={'center':'dual_sim'}>,
#         <AxesSubplot:title={'center':'front_cam'}>],
#        [<AxesSubplot:title={'center':'four_g'}>,
#         <AxesSubplot:title={'center':'internal_memory'}>,
#         <AxesSubplot:title={'center':'mob_depth'}>,
#         <AxesSubplot:title={'center':'mobile_wt'}>,
#         <AxesSubplot:title={'center':'n_cores'}>],
#        [<AxesSubplot:title={'center':'primary_cam'}>,
#         <AxesSubplot:title={'center':'px_height'}>,
#         <AxesSubplot:title={'center':'px_width'}>,
#         <AxesSubplot:title={'center':'ram'}>,
#         <AxesSubplot:title={'center':'screen_h'}>],
#        [<AxesSubplot:title={'center':'screen_w'}>,
#         <AxesSubplot:title={'center':'talk_time'}>,
#         <AxesSubplot:title={'center':'three_g'}>,
#         <AxesSubplot:title={'center':'touch_screen'}>,
#         <AxesSubplot:title={'center':'wifi'}>],
#        [<AxesSubplot:title={'center':'price_range'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
Correlation = d.corr()
# Out:
#                  price_range
# price_range         1.000000
# ram                 0.917046
# battery_power       0.200723
# px_width            0.165818
# px_height           0.148858
# internal_memory     0.044435
# screen_w            0.038711
# primary_cam         0.033599
# three_g             0.023611
# screen_h            0.022986

# %%
plt.figure(figsize = (20,20))
sns.heatmap(Correlation, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
IF = Correlation['price_range'].sort_values(ascending=False).head(10).to_frame()
IF
# Out:
#                  price_range
# price_range         1.000000
# ram                 0.917046
# battery_power       0.200723
# px_width            0.165818
# px_height           0.148858
# internal_memory     0.044435
# screen_w            0.038711
# primary_cam         0.033599
# three_g             0.023611
# screen_h            0.022986

# %%
sns.catplot(x="price_range",y="ram",data=d)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3')])

# %%
d.loc[(d['price_range']==0) & (d['n_cores']==8)]['n_cores'].count()
# Out:
# 67

# %%
sns.boxplot(x = 'price_range', y = 'battery_power',data = d)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='battery_power'>

# %%
labels = ["3G-supported",'Not supported']
values=d['three_g'].value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
d['front_cam'].hist(alpha=0.5,color='green',label='Front camera')
d['primary_cam'].hist(alpha=0.5,color='yellow',label='Primary camera')
plt.legend()
a=range(21)
plt.xticks(a)
plt.xlabel('MegaPixels')
# Out:
# Text(0.5, 0, 'MegaPixels')

# %%
from numpy import median
a=range(21)
plt.figure(figsize = (20,10))
plt.xticks(a)
ax = sns.histplot(x="primary_cam", data=d,hue='price_range', binwidth=1,multiple="dodge")

# %%
sns.pointplot(y = 'internal_memory', x = 'price_range', data = d)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='internal_memory'>

# %%
sns.pointplot(y="talk_time", x="price_range", data=d)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='talk_time'>

# %%
sns.boxplot(d['touch_screen'],d['price_range'])
plt.show()
# Out:
# /Users/akaash/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import warnings; warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# Split data into training and testing
X= d.iloc[:,:-1]
Y=d.iloc[:,20]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)


# Specify Classifier
mlp = MLPClassifier(max_iter=100)

# Hyper-parameter space to optimize MLP
parameter_space = {
    'hidden_layer_sizes': [(8,4), (24,12), (48,24), (96,48)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05, 0.1],
    'learning_rate': ['constant','adaptive'],
}

# Note: the max_iter=100 that you defined on the initializer is not in the grid. 
# So, that number will be constant, while the ones in the grid will be searched.

# Run Search
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=3, estimator=MLPClassifier(max_iter=100), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.05, 0.1],
#                          'hidden_layer_sizes': [(8, 4), (24, 12), (48, 24),
#                                                 (96, 48)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']})

# %%
print('Best parameters found:\n', clf.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.371 (+/-0.152) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.468 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.437 (+/-0.047) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.444 (+/-0.096) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.492 (+/-0.060) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.527 (+/-0.072) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.496 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.548 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.475 (+/-0.010) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.563 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.533 (+/-0.061) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.556 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.549 (+/-0.036) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.587 (+/-0.074) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.530 (+/-0.093) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.631 (+/-0.087) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.435 (+/-0.007) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.464 (+/-0.053) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.456 (+/-0.083) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.485 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.477 (+/-0.036) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.520 (+/-0.057) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.485 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.531 (+/-0.047) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.523 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.585 (+/-0.066) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.499 (+/-0.072) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.572 (+/-0.061) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.533 (+/-0.025) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.603 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.543 (+/-0.019) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.654 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.444 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.413 (+/-0.015) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.433 (+/-0.052) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.442 (+/-0.087) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.478 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.569 (+/-0.100) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.479 (+/-0.067) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.535 (+/-0.030) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.487 (+/-0.036) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.629 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.530 (+/-0.031) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.581 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.535 (+/-0.034) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.645 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.541 (+/-0.036) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.649 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.251 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.257 (+/-0.022) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.249 (+/-0.007) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.318 (+/-0.190) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.464 (+/-0.166) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.313 (+/-0.190) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.501 (+/-0.194) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.263 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.594 (+/-0.060) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.255 (+/-0.002) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.589 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.251 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.613 (+/-0.091) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.249 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.610 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.249 (+/-0.007) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.256 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.249 (+/-0.007) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.288 (+/-0.326) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.263 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.590 (+/-0.057) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.405 (+/-0.314) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.626 (+/-0.015) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.645 (+/-0.072) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.592 (+/-0.113) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.253 (+/-0.002) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.627 (+/-0.095) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.337 (+/-0.254) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.325 (+/-0.135) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.245 (+/-0.002) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.456 (+/-0.317) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.250 (+/-0.009) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.452 (+/-0.131) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (24, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.597 (+/-0.039) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.255 (+/-0.002) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.631 (+/-0.021) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (48, 24), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.262 (+/-0.020) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.615 (+/-0.024) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.252 (+/-0.009) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.566 (+/-0.030) for {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
# Now you can use the clf to make new predictions. 
# For example, check the performance on your test set.    
y_true, y_pred = Y_test , clf.predict(X_test)

# Confustion Matrix
from sklearn.metrics import f1_score,confusion_matrix,accuracy_score
c = confusion_matrix(y_true,y_pred)
print('Confusion Matrix:\n', c, '\n')
#sns.heatmap(cm,annot=True,fmt="d", annot_kws={"size": 12}) # font size

# Classification Report
from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))

print(accuracy_score(y_true, y_pred))
# Out:
# Confusion Matrix:
#  [[ 98  31   3   0]
#  [ 20  75  14   9]
#  [  0  17  56  47]
#  [  0   0  19 111]]
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78       132
#            1       0.61      0.64      0.62       118
#            2       0.61      0.47      0.53       120
#            3       0.66      0.85      0.75       130
#
#     accuracy                           0.68       500
#    macro avg       0.68      0.67      0.67       500
# weighted avg       0.68      0.68      0.67       500
#
# 0.68

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif, mutual_info_classif

# ---------------------------------------------------------------------------
# We should be selecting features using TRAINING Dataset and NOT FULL Dataset - Fix This
# ---------------------------------------------------------------------------

# Get ready to plot scores from Univariate Feature Selection Methods
plt.figure(figsize=(18,10)); plt.clf()
x_indices = np.arange(X.shape[-1])

# SelectKBest Features using F-Test
x_new_f = SelectKBest(f_classif, k=6)
x_new_f.fit_transform(X, Y)
#scores = x_new_f.pvalues_
#scores = -np.log10(x_new_f.pvalues_)
scores = x_new_f.scores_
scores /= scores.max()
plt.bar(x_indices - .45, scores, width=.15,
        label='F-Test score', color='darkorange',
        edgecolor='black')

# Print Selected Features
print('F-Test Feature Scores List: \n', x_new_f.scores_)
print('Feature List: \n', x.columns, '\n')



# Finish Plotting
plt.title("Comparing Univariate Feature Selection")
plt.xlabel('Feature number')
plt.yticks(())
plt.axis('tight')
plt.legend(loc='upper right')
plt.show()

# Re-Run to Get Datasets
x_new_f = SelectKBest(f_classif, k=6).fit_transform(X, Y)
#x_new_chi2 = SelectKBest(chi2, k=6).fit_transform(X, Y)
#x_new_mi = SelectKBest(mutual_info_classif, k=6).fit_transform(x, y)
# Out:
# F-Test Feature Scores List:
#  [8.97646669e-03 1.35441108e-04 1.40253482e-04 1.21655058e-04
#  2.19362969e-04 3.00991809e-04 8.30370470e-04 4.26316816e-04
#  1.02108097e-03 7.45833096e-04 2.34494423e-04 5.53529214e-03
#  6.42618475e-03 1.00000000e+00 6.32361834e-04 4.74700916e-04
#  4.62715917e-04 1.29916293e-04 3.67403839e-04 8.09464485e-05]
# Feature List:
#  Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen'],
#       dtype='object')

# %%
SelectKBest(f_classif, k=6)
# Out:
# SelectKBest(k=6)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_new_f, Y, test_size=0.25, random_state=42)


mlp = MLPClassifier(max_iter=100)

# Hyper-parameter space to optimize MLP
parameter_space = {
    'hidden_layer_sizes': [(8,4), (24,12), (48,24), (96,48)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05, 0.1],
    'learning_rate': ['constant','adaptive'],
}

# Run Search
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(x_new_f, Y)

# Best parameter set
print('Best parameters found:\n', clf.best_params_,'\n')

# Now you can use the clf to make new predictions. 
# For example, check the performance on your test set.    
y_true, y_pred = Y_test , clf.predict(X_test)

# Confustion Matrix
from sklearn.metrics import f1_score,confusion_matrix
m = confusion_matrix(y_true,y_pred)
print('Confusion Matrix:\n', m, '\n')
#sns.heatmap(cm,annot=True,fmt="d", annot_kws={"size": 12}) # font size

# Classification Report
from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (96, 48), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Confusion Matrix:
#  [[109  18   4   1]
#  [ 15  65  26  12]
#  [  0  19  59  42]
#  [  0   1  22 107]]
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       132
#            1       0.63      0.55      0.59       118
#            2       0.53      0.49      0.51       120
#            3       0.66      0.82      0.73       130
#
#     accuracy                           0.68       500
#    macro avg       0.68      0.67      0.67       500
# weighted avg       0.68      0.68      0.68       500

# %%
X_train, X_test, Y_train, _test = train_test_split(x_new_chi2, y, test_size=0.25, random_state=42)

# Specify Classifier
mlp = MLPClassifier(max_iter=100)

# Hyper-parameter space to optimize MLP
parameter_space = {
    'hidden_layer_sizes': [(8,4), (24,12), (48,24), (96,48)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05, 0.1],
    'learning_rate': ['constant','adaptive'],
}

# Run Search
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)

# Best parameter set
print('Best parameters found:\n', clf.best_params_,'\n')

# Now you can use the clf to make new predictions. 
# For example, check the performance on your test set.    
y_true, y_pred = y_test , clf.predict(X_test)

# Confustion Matrix
from sklearn.metrics import f1_score,confusion_matrix
cm = confusion_matrix(y_true,y_pred)
print('Confusion Matrix:\n', cm, '\n')
#sns.heatmap(cm,annot=True,fmt="d", annot_kws={"size": 12}) # font size

# Classification Report
from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

sffs = SFS(mlp,
         k_features=6,
         forward=True,
         floating=False,
        scoring='accuracy',
         cv=5)
sffs.fit(X_train, Y_train)
sffs.k_feature_names_
# Out:
# ('battery_power',
#  'dual_sim',
#  'internal_memory',
#  'mobile_wt',
#  'ram',
#  'talk_time')

# %%
# Out:
#             feature_idx                                          cv_scores  \
# 1                  (6,)  [0.27, 0.2633333333333333, 0.30333333333333334...
# 2               (6, 13)  [0.4, 0.44666666666666666, 0.39666666666666667...
# 3            (6, 8, 13)                     [0.56, 0.63, 0.52, 0.59, 0.62]
# 4         (3, 6, 8, 13)  [0.6966666666666667, 0.6233333333333333, 0.546...
# 5     (3, 6, 8, 13, 16)  [0.63, 0.6133333333333333, 0.6566666666666666,...
# 6  (0, 3, 6, 8, 13, 16)  [0.6433333333333333, 0.6566666666666666, 0.583...
#
#   avg_score                                      feature_names  ci_bound  \
# 1  0.267333                                 (internal_memory,)  0.025186
# 2     0.426                             (internal_memory, ram)  0.034743
# 3     0.584                  (internal_memory, mobile_wt, ram)  0.051796
# 4     0.614        (dual_sim, internal_memory, mobile_wt, ram)  0.064771
# 5  0.618667  (dual_sim, internal_memory, mobile_wt, ram, ta...  0.030246
# 6  0.637333  (battery_power, dual_sim, internal_memory, mob...  0.037192
#
#     std_dev   std_err
# 1  0.019596  0.009798
# 2  0.027031  0.013515
# 3  0.040299  0.020149
# 4  0.050394  0.025197
# 5  0.023532  0.011766
# 6  0.028937  0.014468

# %%
sffs.subsets_
# Out:
# {1: {'feature_idx': (15,),
#   'cv_scores': array([0.277]),
#   'avg_score': 0.277,
#   'feature_names': ('screen_w',)},
#  2: {'feature_idx': (9, 15),
#   'cv_scores': array([0.2955]),
#   'avg_score': 0.2955,
#   'feature_names': ('n_cores', 'screen_w')},
#  3: {'feature_idx': (9, 13, 15),
#   'cv_scores': array([0.4895]),
#   'avg_score': 0.4895,
#   'feature_names': ('n_cores', 'ram', 'screen_w')},
#  4: {'feature_idx': (8, 9, 13, 15),
#   'cv_scores': array([0.6115]),
#   'avg_score': 0.6115,
#   'feature_names': ('mobile_wt', 'n_cores', 'ram', 'screen_w')},
#  5: {'feature_idx': (6, 8, 9, 13, 15),
#   'cv_scores': array([0.6385]),
#   'avg_score': 0.6385,
#   'feature_names': ('internal_memory',
#    'mobile_wt',
#    'n_cores',
#    'ram',
#    'screen_w')},
#  6: {'feature_idx': (4, 6, 8, 9, 13, 15),
#   'cv_scores': array([0.651]),
#   'avg_score': 0.651,
#   'feature_names': ('front_cam',
#    'internal_memory',
#    'mobile_wt',
#    'n_cores',
#    'ram',
#    'screen_w')}}

# %%
sffs.k_feature_idx_
# Out:
# (4, 6, 8, 9, 13, 15)

# %%
X_train_sfs = sffs.transform(X_train)
X_test_sfs = sffs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
mlp.fit(X_train_sfs, y_train)
y_pred = mlp.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Test set accuracy: 56.00 %

# %%
import pandas as pd
pd.DataFrame.from_dict(sffs.get_metric_dict()).T
# Out:
#             feature_idx                                          cv_scores  \
# 1                  (6,)  [0.27, 0.2633333333333333, 0.30333333333333334...
# 2               (6, 13)  [0.4, 0.44666666666666666, 0.39666666666666667...
# 3            (6, 8, 13)                     [0.56, 0.63, 0.52, 0.59, 0.62]
# 4         (3, 6, 8, 13)  [0.6966666666666667, 0.6233333333333333, 0.546...
# 5     (3, 6, 8, 13, 16)  [0.63, 0.6133333333333333, 0.6566666666666666,...
# 6  (0, 3, 6, 8, 13, 16)  [0.6433333333333333, 0.6566666666666666, 0.583...
#
#   avg_score                                      feature_names  ci_bound  \
# 1  0.267333                                 (internal_memory,)  0.025186
# 2     0.426                             (internal_memory, ram)  0.034743
# 3     0.584                  (internal_memory, mobile_wt, ram)  0.051796
# 4     0.614        (dual_sim, internal_memory, mobile_wt, ram)  0.064771
# 5  0.618667  (dual_sim, internal_memory, mobile_wt, ram, ta...  0.030246
# 6  0.637333  (battery_power, dual_sim, internal_memory, mob...  0.037192
#
#     std_dev   std_err
# 1  0.019596  0.009798
# 2  0.027031  0.013515
# 3  0.040299  0.020149
# 4  0.050394  0.025197
# 5  0.023532  0.011766
# 6  0.028937  0.014468
